# %%
# 初始化執行環境
import qlib
from qlib.contrib.data.handler import Alpha360
from qlib.data import D

qlib.init(provider_uri='~/.qlib/qlib_data/my_data/')
instruments = D.instruments(market='all')
# Out:
# [37298:MainThread](2021-01-30 19:36:33,463) INFO - qlib.Initialization - [config.py:277] - default_conf: client.
# [37298:MainThread](2021-01-30 19:36:33,467) WARNING - qlib.Initialization - [config.py:292] - redis connection failed(host=127.0.0.1 port=6379), cache will not be used!
# [37298:MainThread](2021-01-30 19:36:34,196) INFO - qlib.Initialization - [__init__.py:46] - qlib successfully initialized based on client settings.
# [37298:MainThread](2021-01-30 19:36:34,198) INFO - qlib.Initialization - [__init__.py:47] - data_path=/home/kenneth/.qlib/qlib_data/my_data

# %%
data_handler_config = {
    'start_time': '2019-01-01',
    'end_time': '2021-01-15',
    'fit_start_time': '2019-01-01',
    'fit_end_time': '2020-06-30',
    'instruments': instruments,
    'freq': '30m'
}

h = Alpha360(**data_handler_config)

print(h.get_cols())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pyqlib-0.6.1.99-py3.8-linux-x86_64.egg/qlib/data/data.py in features(self, instruments, fields, start_time, end_time, freq, disk_cache)
#     966         try:
# --> 967             return DatasetD.dataset(instruments, fields, start_time, end_time, freq, disk_cache)
#     968         except TypeError:
#
# TypeError: dataset() takes from 3 to 6 positional arguments but 7 were given
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-baee302976db> in <module>
#       8 }
#       9
# ---> 10 h = Alpha360(**data_handler_config)
#      11
#      12 print(h.get_cols())
#
# ~/.local/lib/python3.8/site-packages/pyqlib-0.6.1.99-py3.8-linux-x86_64.egg/qlib/contrib/data/handler.py in __init__(self, instruments, start_time, end_time, freq, infer_processors, learn_processors, fit_start_time, fit_end_time, filter_pipe, **kwargs)
#      72         }
#      73
# ---> 74         super().__init__(
#      75             instruments=instruments,
#      76             start_time=start_time,
#
# ~/.local/lib/python3.8/site-packages/pyqlib-0.6.1.99-py3.8-linux-x86_64.egg/qlib/data/dataset/handler.py in __init__(self, instruments, start_time, end_time, freq, data_loader, infer_processors, learn_processors, process_type, drop_raw, **kwargs)
#     329         self.process_type = process_type
#     330         self.drop_raw = drop_raw
# --> 331         super().__init__(instruments, start_time, end_time, freq, data_loader, **kwargs)
#     332
#     333     def get_all_processors(self):
#
# ~/.local/lib/python3.8/site-packages/pyqlib-0.6.1.99-py3.8-linux-x86_64.egg/qlib/data/dataset/handler.py in __init__(self, instruments, start_time, end_time, freq, data_loader, init_data, fetch_orig)
#     100         if init_data:
#     101             with TimeInspector.logt("Init data"):
# --> 102                 self.init()
#     103         super().__init__()
#     104
#
# ~/.local/lib/python3.8/site-packages/pyqlib-0.6.1.99-py3.8-linux-x86_64.egg/qlib/data/dataset/handler.py in init(self, init_type, enable_cache)
#     413         """
#     414         # init raw data
# --> 415         super().init(enable_cache=enable_cache)
#     416
#     417         with TimeInspector.logt("fit & process data"):
#
# ~/.local/lib/python3.8/site-packages/pyqlib-0.6.1.99-py3.8-linux-x86_64.egg/qlib/data/dataset/handler.py in init(self, enable_cache)
#     124         # _data may be with multiple column index level. The outer level indicates the feature set name
#     125         with TimeInspector.logt("Loading data"):
# --> 126             self._data = self.data_loader.load(self.instruments, self.start_time, self.end_time, self.freq)
#     127         # TODO: cache
#     128
#
# ~/.local/lib/python3.8/site-packages/pyqlib-0.6.1.99-py3.8-linux-x86_64.egg/qlib/data/dataset/loader.py in load(self, instruments, start_time, end_time, freq)
#     122         if self.is_group:
#     123             df = pd.concat(
# --> 124                 {
#     125                     grp: self.load_group_df(instruments, exprs, names, start_time, end_time, freq)
#     126                     for grp, (exprs, names) in self.fields.items()
#
# ~/.local/lib/python3.8/site-packages/pyqlib-0.6.1.99-py3.8-linux-x86_64.egg/qlib/data/dataset/loader.py in <dictcomp>(.0)
#     123             df = pd.concat(
#     124                 {
# --> 125                     grp: self.load_group_df(instruments, exprs, names, start_time, end_time, freq)
#     126                     for grp, (exprs, names) in self.fields.items()
#     127                 },
#
# ~/.local/lib/python3.8/site-packages/pyqlib-0.6.1.99-py3.8-linux-x86_64.egg/qlib/data/dataset/loader.py in load_group_df(self, instruments, exprs, names, start_time, end_time, freq)
#     170             warnings.warn("`filter_pipe` is not None, but it will not be used with `instruments` as list")
#     171
# --> 172         df = D.features(instruments, exprs, start_time, end_time, freq)
#     173         df.columns = names
#     174         if self.swap_level:
#
# ~/.local/lib/python3.8/site-packages/pyqlib-0.6.1.99-py3.8-linux-x86_64.egg/qlib/data/data.py in features(self, instruments, fields, start_time, end_time, freq, disk_cache)
#     967             return DatasetD.dataset(instruments, fields, start_time, end_time, freq, disk_cache)
#     968         except TypeError:
# --> 969             return DatasetD.dataset(instruments, fields, start_time, end_time, freq)
#     970
#     971
#
# ~/.local/lib/python3.8/site-packages/pyqlib-0.6.1.99-py3.8-linux-x86_64.egg/qlib/data/data.py in dataset(self, instruments, fields, start_time, end_time, freq)
#     690
#     691     def dataset(self, instruments, fields, start_time=None, end_time=None, freq="day"):
# --> 692         instruments_d = self.get_instruments_d(instruments, freq)
#     693         column_names = self.get_column_names(fields)
#     694         cal = Cal.calendar(start_time, end_time, freq)
#
# ~/.local/lib/python3.8/site-packages/pyqlib-0.6.1.99-py3.8-linux-x86_64.egg/qlib/data/data.py in get_instruments_d(instruments, freq)
#     368             if "market" in instruments:
#     369                 # dict of stockpool config
# --> 370                 instruments_d = Inst.list_instruments(instruments=instruments, freq=freq, as_list=False)
#     371             else:
#     372                 # dict of instruments and timestamp
#
# ~/.local/lib/python3.8/site-packages/pyqlib-0.6.1.99-py3.8-linux-x86_64.egg/qlib/data/data.py in list_instruments(self, instruments, start_time, end_time, freq, as_list)
#     595         # strip
#     596         # use calendar boundary
# --> 597         cal = Cal.calendar(freq=freq)
#     598         start_time = pd.Timestamp(start_time or cal[0])
#     599         end_time = pd.Timestamp(end_time or cal[-1])
#
# ~/.local/lib/python3.8/site-packages/pyqlib-0.6.1.99-py3.8-linux-x86_64.egg/qlib/data/data.py in calendar(self, start_time, end_time, freq, future)
#     532
#     533     def calendar(self, start_time=None, end_time=None, freq="day", future=False):
# --> 534         _calendar, _calendar_index = self._get_calendar(freq, future)
#     535         if start_time == "None":
#     536             start_time = None
#
# ~/.local/lib/python3.8/site-packages/pyqlib-0.6.1.99-py3.8-linux-x86_64.egg/qlib/data/data.py in _get_calendar(self, freq, future)
#     118             _calendar, _calendar_index = H["c"][flag]
#     119         else:
# --> 120             _calendar = np.array(self.load_calendar(freq, future))
#     121             _calendar_index = {x: i for i, x in enumerate(_calendar)}  # for fast search
#     122             H["c"][flag] = _calendar, _calendar_index
#
# ~/.local/lib/python3.8/site-packages/pyqlib-0.6.1.99-py3.8-linux-x86_64.egg/qlib/data/data.py in load_calendar(self, freq, future)
#     527             fname = self._uri_cal.format(freq)
#     528         if not os.path.exists(fname):
# --> 529             raise ValueError("calendar not exists for freq " + freq)
#     530         with open(fname) as f:
#     531             return [pd.Timestamp(x.strip()) for x in f]
#
# ValueError: calendar not exists for freq day
